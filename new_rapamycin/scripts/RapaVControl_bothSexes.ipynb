# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import datetime
from scipy import stats
from statsmodels.stats.anova import anova_lm
from statsmodels.formula.api import ols
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.nonparametric.smoothers_lowess import lowess
from Bio.SeqIO.FastaIO import SimpleFastaParser
import os
from upsetplot import UpSet
from upsetplot import from_contents

custom_params = {"axes.spines.right": False, "axes.spines.top": False}
sns.set_theme(style="ticks", rc=custom_params)

#run_type = "dry"
run_type = "wet"


new_day = datetime.datetime.now().strftime("%Y%m%d")

palette = {"Control":"#000000", "Rapa Adult":"#5a9f68", 
           "Rapa Early":"#4170b0", "Rapa Late":"#c34e0d"}

path = "../analysis/plots/new_plots_forYuXuan/"

# %%
# Read fasta with ASV names to put OTU into our dataframe
with open('../analysis/CLEAN_ASVs_merged.fa') as fasta_file:  # Will close handle cleanly
    identifiers = []
    seqs = []
    for title, sequence in SimpleFastaParser(fasta_file):
        identifiers.append(title.split(None, 1)[0])  # First word is ID
        seqs.append(sequence)

fasta_tuples = list(zip(identifiers, seqs))
df_fa = pd.DataFrame(fasta_tuples, columns = ["OTU", "sequence"])

# %%
# Define the directory containing the files
data_dir = "../analysis/deseq_timepoints_new/"

# List all files in the directory
all_files = os.listdir(data_dir)
csv_files = [f for f in all_files if f.endswith(".csv")]
csv_files = [f for f in csv_files if f.startswith("AGE_")]

# Create an empty dictionary to store dataframes
data_dict = {}

# Loop through each file
for filename in csv_files:
    # Extract key (filename before second underscore)
    #key = '_'.join(filename.split("_")[0:4])
    key = filename
  
    # Read the file and store in the dictionary
    data_dict[key] = pd.read_csv(os.path.join(data_dir, filename), sep=";")

# Concatenate the dataframes using the dictionary
mat = pd.concat(data_dict.values(), keys=data_dict.keys())

# %%
mat.reset_index(inplace = True)
mat.columns = ["fullname", "trash", "sequence", 'baseMean', 'log2FoldChange', 'lfcSE', 'stat', 'pvalue',
       'padj', 'Kingdom', 'Phylum', 'Class', 'Order', 'Family', 'Genus']
mat.drop(columns = ["trash"], inplace = True)

# %%
# Make a tax column to compare to lefse
mat["tax"] = mat[["Kingdom", "Phylum", "Class", "Order", "Family", "Genus"]].astype(str).agg("_".join, axis = 1)
mat["tax"] = list(mat["tax"].str.replace("_nan", "_NA"))

# Merge matrix with FC and stuff with the correspondence to otu name
mer = pd.merge(mat, df_fa, how = "left", on = "sequence")

# %%
di = {'AGE_Mid_Old_Rapa Early_20240606.csv':"MidOld_RapaEarly",
       'AGE_YoungRapa Adult_OldRapa Early_Rapa Early_20240606.csv':"YoungRapaAdult_OldRapaEarly",
       'AGE_MidRapa Adult_OldRapa Late_Rapa Early_20240606.csv':"MidRapaAdult_OldRapaLate",
       'AGE_YoungRapa Adult_MidRapa Early_Rapa Early_20240606.csv':"YoungRapaAdult_MidRapaEarly",
       'AGE_Young_Mid_Control_20240606.csv':"YoungMid_Control",
       'AGE_Mid_Old_Control_20240606.csv':"MidOld_Control",
       'AGE_Young_Mid_Rapa Adult_20240606.csv':"YoungMid_RapaAdult",
       'AGE_Young_Old_Rapa Adult_20240606.csv':"YoungOld_RapaAdult",
       'AGE_Mid_Old_Rapa Adult_20240606.csv':"MidOld_RapaAdult",
       'AGE_MidControl_OldRapa Late_Rapa Early_20240606.csv':"MidControl_OldRapaLate",
       'AGE_Young_Old_Control_20240606.csv':"YoungOld_Control"}
mer = mer.replace({"fullname": di})

# %%
merX = mer[mer["log2FoldChange"] > 0]

# %%
RapaAdult_YoungOld = merX[merX["fullname"] == "YoungOld_RapaAdult"]["OTU"]
RapaAdult_MidOld = merX[merX["fullname"] == "MidOld_RapaAdult"]["OTU"]
RapaAdult_YoungMid = merX[merX["fullname"] == "YoungMid_RapaAdult"]["OTU"]

Control_YoungOld = merX[merX["fullname"] == "YoungOld_Control"]["OTU"]
Control_MidOld = merX[merX["fullname"] == "MidOld_Control"]["OTU"]
Control_YoungMid = merX[merX["fullname"] == "YoungMid_Control"]["OTU"]

# %%
changes = from_contents(
    {"RapaAdult_YoungMid": RapaAdult_YoungMid, "RapaAdult_MidOld": RapaAdult_MidOld,
    "Control_MidOld":Control_MidOld, "Control_YoungMid":Control_YoungMid}
)

ax_dict = UpSet(changes, subset_size="count", show_counts=True).plot()
matplotlib.rcParams['pdf.fonttype'] = 42
plt.tight_layout()
plt.savefig(f"{path}/Upregulated_uppset.pdf")
# Out:
# /var/folders/1d/m_275l6153b26smzn9vx6txh0000gp/T/ipykernel_80667/2810824567.py:8: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
pd.Series(list(set(RapaAdult_YoungMid) & set(RapaAdult_MidOld)))
# Out:
# 0    ASV_89
# dtype: object

# %%
merX = mer[mer["log2FoldChange"] < 0]

# %%
RapaAdult_YoungOld = merX[merX["fullname"] == "YoungOld_RapaAdult"]["OTU"]
RapaAdult_MidOld = merX[merX["fullname"] == "MidOld_RapaAdult"]["OTU"]
RapaAdult_YoungMid = merX[merX["fullname"] == "YoungMid_RapaAdult"]["OTU"]

Control_YoungOld = merX[merX["fullname"] == "YoungOld_Control"]["OTU"]
Control_MidOld = merX[merX["fullname"] == "MidOld_Control"]["OTU"]
Control_YoungMid = merX[merX["fullname"] == "YoungMid_Control"]["OTU"]

# %%
changes = from_contents(
    {"RapaAdult_YoungMid": RapaAdult_YoungMid, "RapaAdult_MidOld": RapaAdult_MidOld,
    "Control_MidOld":Control_MidOld, "Control_YoungMid":Control_YoungMid}
)

ax_dict = UpSet(changes, subset_size="count", show_counts=True).plot()
matplotlib.rcParams['pdf.fonttype'] = 42
plt.tight_layout()
plt.savefig(f"{path}/Downregulated_uppset.pdf")
# Out:
# /var/folders/1d/m_275l6153b26smzn9vx6txh0000gp/T/ipykernel_80667/953847550.py:8: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
pd.Series(list(set(RapaAdult_YoungMid) & set(RapaAdult_MidOld)))
# Out:
# 0    ASV_93
# dtype: object

# %%
upreg = mer[mer["log2FoldChange"] > 0]
upreg["reg"] = "up_in_older"
downreg = mer[mer["log2FoldChange"] < 0]
downreg["reg"] = "down_in_older"

mer = pd.concat([upreg, downreg])
# Out:
# /var/folders/1d/m_275l6153b26smzn9vx6txh0000gp/T/ipykernel_80667/31300130.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   upreg["reg"] = "up_in_older"
# /var/folders/1d/m_275l6153b26smzn9vx6txh0000gp/T/ipykernel_80667/31300130.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downreg["reg"] = "down_in_older"

# %%
## Do chronics
chronics = mer[mer["fullname"].isin(["YoungMid_RapaAdult",
                                  'YoungMid_Control',
                                   'MidOld_Control',
                                  'MidOld_RapaAdult'])]

# %%
palettesex = {'AGE_Young_Mid_Control_20240606.csv': '#000000',
 'AGE_Young_Mid_Rapa Adult_20240606.csv': '#c34e0d',
 'AGE_Mid_Old_Control_20240606.csv': '#000000',
 'AGE_Mid_Old_Rapa Adult_20240606.csv': '#c34e0d'}

custom_params = {"axes.spines.right": False, "axes.spines.top": False}
sns.set_theme(style="ticks", rc=custom_params)

fig, ax = plt.subplots(figsize = (10, 6))
# Create the bar plot
sns.countplot(chronics, x="fullname",
             order = ['YoungMid_Control', 
            "YoungMid_RapaAdult", 'MidOld_Control',
            'MidOld_RapaAdult'], hue = "reg")

plt.xlabel("Age Group")
plt.ylabel("Count DA ASVs")
plt.xticks(rotation=45)  # rotate x-axis labels for better readability

matplotlib.rcParams['pdf.fonttype'] = 42
plt.tight_layout()
plt.savefig(f"{path}/RapavControl_barplot.pdf")
plt.savefig(f"{path}/RapavControl_barplot.png")

# %% [markdown]
# ## Plot expression of these bacteria

# %%
norm_otu = pd.read_csv("../analysis/norm-CLEAN_ASVs_counts_merged_20240530.tsv", sep = "\t")
norm_otu.set_index('Sample_ID', inplace = True)
metadata = pd.read_csv("../metadata_rapaInter.csv")

# Sort metadata according to columnames to help understand groups
sorter = list(norm_otu.columns[1:])
metadata.Sample_ID = metadata.Sample_ID.astype("category")
metadata.Sample_ID = metadata.Sample_ID.cat.set_categories(sorter)
metadata = metadata.sort_values(["Sample_ID"])
metadata.set_index("Sample_ID", inplace = True)

# Transpose df and merge with metadata
expr = pd.merge(norm_otu.T, metadata, left_index = True, right_index = True)

# %%
# Read fasta with ASV names to put OTU into our dataframe
with open('../analysis/CLEAN_ASVs_merged.fa') as fasta_file:  # Will close handle cleanly
    identifiers = []
    seqs = []
    for title, sequence in SimpleFastaParser(fasta_file):
        identifiers.append(title.split(None, 1)[0])  # First word is ID
        seqs.append(sequence)

fasta_tuples = list(zip(identifiers, seqs))
df_fa = pd.DataFrame(fasta_tuples, columns = ["OTU", "sequence"])

# Define the directory containing the files
data_dir = "../analysis/deseq_timepoints_new/"

# List all files in the directory
all_files = os.listdir(data_dir)
csv_files = [f for f in all_files if f.endswith(".csv")]

# Create an empty dictionary to store dataframes
data_dict = {}

# Loop through each file
for filename in csv_files:
    # Extract key (filename before second underscore)
    key = '_'.join(filename.split("_")[0:3])
  
    # Read the file and store in the dictionary
    data_dict[key] = pd.read_csv(os.path.join(data_dir, filename), sep=";")

# Concatenate the dataframes using the dictionary
mat = pd.concat(data_dict.values(), keys=data_dict.keys())

mat.reset_index(inplace = True)
mat.columns = ["fullname", "trash", "sequence", 'baseMean', 'log2FoldChange', 'lfcSE', 'stat', 'pvalue',
       'padj', 'Kingdom', 'Phylum', 'Class', 'Order', 'Family', 'Genus']
mat.drop(columns = ["trash"], inplace = True)
mat[["Comparison", "fullname"]] = mat["fullname"].str.split('_', n=1, expand=True)
mat[["Age", "Sex"]] = mat["fullname"].str.split('_', n=1, expand=True)
mat.drop(columns = ["fullname"], inplace = True)
# Make a tax column to compare to lefse
mat["tax"] = mat[["Kingdom", "Phylum", "Class", "Order", "Family", "Genus"]].astype(str).agg("_".join, axis = 1)
mat["tax"] = list(mat["tax"].str.replace("_nan", "_NA"))

# Merge matrix with FC and stuff with the correspondence to otu name
mer = pd.merge(mat, df_fa, how = "left", on = "sequence")

# %%
e = "ASV_33"
list(mer[mer["OTU"] == e]["Genus"].unique())[-1]
# Out:
# 'Parasutterella'

# %%
ots = {}

for e in ["ASV_33", "ASV_378", "ASV_89", "ASV_3", "ASV_93"]:
    ots[list(mer[mer["OTU"] == e]["Genus"].unique())[-1]] = e
    print(e)
    display(mer[mer["OTU"] == e].loc[:, ["log2FoldChange", "padj", "Comparison", "Age", "Sex", "Family", "Genus"]])
# Out:
# ASV_33
#       log2FoldChange          padj          Comparison            Age  \
# 87          1.813410  3.469111e-03                 AGE            Mid
# 238         1.301175  3.836839e-03  RapaAdultRapaEarly            Mid
# 436         1.741069  4.524443e-03                 AGE  MidRapa Adult
# 557        -2.931820  5.335338e-06    ControlRapaAdult            Mid
# 863        -2.372181  4.115311e-02        SexRapaEarly            Old
# 1299       -2.252496  3.611985e-02            AGEMales            Mid
# 1401       -1.539543  4.050308e-02    ControlRapaEarly            Mid
# 1464       -2.621701  2.919787e-03    ControlRapaAdult            Mid
# 1592       -1.911015  3.424773e-02    ControlRapaEarly            Mid
# 1936       -2.825330  4.141216e-09    ControlRapaAdult            Mid
# 2022       -4.169117  1.092924e-07        SexRapaAdult            Old
# 2575       -1.973347  1.128474e-03    ControlRapaAdult          Young
# 3086        1.460475  2.576205e-02  RapaAdultRapaEarly            Mid
#
#                Sex            Family           Genus
# 87             Old  Burkholderiaceae  Parasutterella
# 238            ALL  Burkholderiaceae  Parasutterella
# 436   OldRapa Late  Burkholderiaceae  Parasutterella
# 557              M  Burkholderiaceae  Parasutterella
# 863   20240404.csv  Burkholderiaceae  Parasutterella
# 1299           Old  Burkholderiaceae  Parasutterella
# 1401           ALL  Burkholderiaceae  Parasutterella
# 1464             F  Burkholderiaceae  Parasutterella
# 1592             M  Burkholderiaceae  Parasutterella
# 1936           ALL  Burkholderiaceae  Parasutterella
# 2022  20240404.csv  Burkholderiaceae  Parasutterella
# 2575             M  Burkholderiaceae  Parasutterella
# 3086             F  Burkholderiaceae  Parasutterella
# ASV_378
#       log2FoldChange      padj        Comparison              Age  \
# 100         3.486312  0.005786               AGE              Mid
# 204        -6.132132  0.000037          AGEMales  YoungRapa Adult
# 398        -5.951085  0.000001               AGE  YoungRapa Adult
# 604        -4.610795  0.035176  ControlRapaAdult              Mid
# 1339        6.676734  0.000006          AGEMales              Mid
# 1619       -5.066251  0.012172  ControlRapaEarly              Mid
# 2512        5.721499  0.001584               AGE            Young
# 2934       -6.055415  0.031968      SexRapaEarly              Mid
# 3448        5.377770  0.004078          AGEMales    MidRapa Adult
#
#                 Sex                 Family       Genus
# 100             Old  Peptostreptococcaceae  Romboutsia
# 204   OldRapa Early  Peptostreptococcaceae  Romboutsia
# 398   OldRapa Early  Peptostreptococcaceae  Romboutsia
# 604               M  Peptostreptococcaceae  Romboutsia
# 1339            Old  Peptostreptococcaceae  Romboutsia
# 1619              M  Peptostreptococcaceae  Romboutsia
# 2512            Old  Peptostreptococcaceae  Romboutsia
# 2934   20240404.csv  Peptostreptococcaceae  Romboutsia
# 3448   OldRapa Late  Peptostreptococcaceae  Romboutsia
# ASV_89
#       log2FoldChange      padj        Comparison              Age  \
# 94          1.077275  0.048440               AGE              Mid
# 133        -1.721363  0.035311          AGEMales  YoungRapa Adult
# 341        -1.274868  0.016845               AGE  YoungRapa Adult
# 1023       -1.517772  0.047823      SexRapaAdult            Young
# 1199       -1.082276  0.033200               AGE  YoungRapa Adult
# 1542        1.093613  0.002448               AGE            Young
# 1657       -2.566933  0.000077          AGEMales  YoungRapa Adult
# 1829        2.053848  0.000167        AGEFemales            Young
# 1858        1.444126  0.020335        SexControl            Young
# 2458        1.266044  0.010071               AGE            Young
# 2592       -1.546093  0.023835  ControlRapaAdult            Young
# 2857        1.361053  0.031869      SexRapaEarly              Mid
#
#                 Sex           Family                          Genus
# 94              Old  Lachnospiraceae  Lachnospiraceae_NK4A136_group
# 133   OldRapa Early  Lachnospiraceae  Lachnospiraceae_NK4A136_group
# 341   OldRapa Early  Lachnospiraceae  Lachnospiraceae_NK4A136_group
# 1023   20240404.csv  Lachnospiraceae  Lachnospiraceae_NK4A136_group
# 1199  MidRapa Early  Lachnospiraceae  Lachnospiraceae_NK4A136_group
# 1542            Mid  Lachnospiraceae  Lachnospiraceae_NK4A136_group
# 1657  MidRapa Early  Lachnospiraceae  Lachnospiraceae_NK4A136_group
# 1829            Old  Lachnospiraceae  Lachnospiraceae_NK4A136_group
# 1858   20240404.csv  Lachnospiraceae  Lachnospiraceae_NK4A136_group
# 2458            Old  Lachnospiraceae  Lachnospiraceae_NK4A136_group
# 2592              M  Lachnospiraceae  Lachnospiraceae_NK4A136_group
# 2857   20240404.csv  Lachnospiraceae  Lachnospiraceae_NK4A136_group
# ASV_3
#       log2FoldChange          padj          Comparison    Age           Sex  \
# 0          -3.417169  1.575451e-05            AGEMales  Young           Old
# 85         -1.972737  4.960912e-04                 AGE    Mid           Old
# 624        -2.106471  2.681066e-03    ControlRapaAdult    Old             F
# 731        -1.945888  1.867826e-07    ControlRapaAdult  Young           ALL
# 1000       -1.360212  4.235364e-02        SexRapaAdult  Young  20240404.csv
# 1817       -1.820542  1.725776e-02          AGEFemales  Young           Old
# 2429       -2.389412  3.178973e-06                 AGE  Young           Old
# 2563       -2.966363  1.353314e-08    ControlRapaAdult  Young             M
# 2958        1.726387  3.922628e-02  RapaAdultRapaEarly    Old             F
# 3213        1.463981  3.415355e-02        SexRapaAdult    Mid  20240404.csv
#
#               Family Genus
# 0     Muribaculaceae   NaN
# 85    Muribaculaceae   NaN
# 624   Muribaculaceae   NaN
# 731   Muribaculaceae   NaN
# 1000  Muribaculaceae   NaN
# 1817  Muribaculaceae   NaN
# 2429  Muribaculaceae   NaN
# 2563  Muribaculaceae   NaN
# 2958  Muribaculaceae   NaN
# 3213  Muribaculaceae   NaN
# ASV_93
#       log2FoldChange          padj          Comparison              Age  \
# 95         -5.142318  8.864165e-20                 AGE              Mid
# 134        12.031983  3.394756e-37            AGEMales  YoungRapa Adult
# 251        -3.382506  2.376526e-09  RapaAdultRapaEarly              Mid
# 343         8.739442  9.711728e-26                 AGE  YoungRapa Adult
# 453        -3.921074  1.355161e-08                 AGE    MidRapa Adult
# 568         6.515778  1.623898e-17    ControlRapaAdult              Mid
# 654         3.820937  5.756895e-03    ControlRapaAdult              Old
# 756         6.922342  7.772162e-22    ControlRapaAdult            Young
# 1024        3.908752  9.221966e-06        SexRapaAdult            Young
# 1129       -2.694829  1.962845e-02          AGEFemales    MidRapa Adult
# 1202        6.850967  2.051004e-26                 AGE  YoungRapa Adult
# 1310       -5.226803  2.036121e-06            AGEMales              Mid
# 1477        3.746259  1.060513e-03    ControlRapaAdult              Mid
# 1543       -3.406386  5.975176e-08                 AGE            Young
# 1597        3.290897  1.209515e-03    ControlRapaEarly              Mid
# 1660        6.874292  3.121974e-27            AGEMales  YoungRapa Adult
# 1948        5.471056  4.295623e-18    ControlRapaAdult              Mid
# 2186       -3.246211  5.568917e-07  RapaAdultRapaEarly              Mid
# 2378        4.041779  1.602156e-05          AGEFemales  YoungRapa Adult
# 2462       -2.562181  4.588043e-02                 AGE            Young
# 2594        7.109188  8.578878e-23    ControlRapaAdult            Young
# 2859        2.728436  1.784661e-03        SexRapaEarly              Mid
# 3104       -3.959511  8.266615e-07  RapaAdultRapaEarly              Mid
# 3237        2.149868  2.130873e-03        SexRapaAdult              Mid
# 3352        3.424370  4.715511e-03          AGEFemales  YoungRapa Adult
# 3415       -4.517866  3.919235e-07            AGEMales    MidRapa Adult
# 3476        3.506500  2.532963e-03    ControlRapaAdult            Young
#
#                 Sex             Family           Genus
# 95              Old  Staphylococcaceae  Staphylococcus
# 134   OldRapa Early  Staphylococcaceae  Staphylococcus
# 251             ALL  Staphylococcaceae  Staphylococcus
# 343   OldRapa Early  Staphylococcaceae  Staphylococcus
# 453    OldRapa Late  Staphylococcaceae  Staphylococcus
# 568               M  Staphylococcaceae  Staphylococcus
# 654               F  Staphylococcaceae  Staphylococcus
# 756             ALL  Staphylococcaceae  Staphylococcus
# 1024   20240404.csv  Staphylococcaceae  Staphylococcus
# 1129   OldRapa Late  Staphylococcaceae  Staphylococcus
# 1202  MidRapa Early  Staphylococcaceae  Staphylococcus
# 1310            Old  Staphylococcaceae  Staphylococcus
# 1477              F  Staphylococcaceae  Staphylococcus
# 1543            Mid  Staphylococcaceae  Staphylococcus
# 1597              M  Staphylococcaceae  Staphylococcus
# 1660  MidRapa Early  Staphylococcaceae  Staphylococcus
# 1948            ALL  Staphylococcaceae  Staphylococcus
# 2186              M  Staphylococcaceae  Staphylococcus
# 2378  MidRapa Early  Staphylococcaceae  Staphylococcus
# 2462            Old  Staphylococcaceae  Staphylococcus
# 2594              M  Staphylococcaceae  Staphylococcus
# 2859   20240404.csv  Staphylococcaceae  Staphylococcus
# 3104              F  Staphylococcaceae  Staphylococcus
# 3237   20240404.csv  Staphylococcaceae  Staphylococcus
# 3352  OldRapa Early  Staphylococcaceae  Staphylococcus
# 3415   OldRapa Late  Staphylococcaceae  Staphylococcus
# 3476              F  Staphylococcaceae  Staphylococcus

# %%
## Since ASV_3 doesnt have a genus, we will give it the name of the family
ots["Muribaculaceae"] = "ASV_3"
# Remove the nan from the dictionary
ots = {'Parasutterella': ['ASV_33'],
 'Romboutsia': ['ASV_378'],
 'Lachnospiraceae_NK4A136_group': ['ASV_89'],
 'Staphylococcus': ['ASV_93'],
 'Muribaculaceae': ['ASV_3']}

# %%
palettesex = {'Control': '#000000',
 'Rapa Adult': '#c34e0d',
 'Rapa Early': '#5a9f68',
 'Rapa Late': '#4170b0'}

def plot_expression(bacteria):

    df = expr.loc[:, ots[bacteria] + ["Sex", "Treatment", "Age"]]

    ax = sns.boxplot(df, x="Age", y = ots[bacteria][0], hue = "Treatment", palette = palettesex, 
               order = ["Young", "Mid", "Old"], showfliers = False)

    ax = sns.swarmplot(df, x="Age", y = ots[bacteria][0], hue = "Treatment",
                          dodge = True, color = ".25", ax = ax, order = ["Young", "Mid", "Old"])

    plt.xlabel("Age Group")
    plt.ylabel(f"Z-score abundance\n({bacteria} {ots[bacteria][0]})")
    plt.xticks(rotation=45)  # rotate x-axis labels for better readability
    sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))

    matplotlib.rcParams['pdf.fonttype'] = 42
    plt.tight_layout()
    plt.savefig(f"{path}/{bacteria}_expression.pdf")
    plt.savefig(f"{path}/{bacteria}_expression.png")
    plt.show()

# %%
for e in list(ots.keys()):
    print(e)
    plot_expression(e)
# Out:
# Parasutterella
# /Users/CMonzo/software/miniconda/lib/python3.9/site-packages/seaborn/categorical.py:166: FutureWarning: Setting a gradient palette using color= is deprecated and will be removed in version 0.13. Set `palette='dark:.25'` for same effect.
#   warnings.warn(msg, FutureWarning)
# Romboutsia
# /Users/CMonzo/software/miniconda/lib/python3.9/site-packages/seaborn/categorical.py:166: FutureWarning: Setting a gradient palette using color= is deprecated and will be removed in version 0.13. Set `palette='dark:.25'` for same effect.
#   warnings.warn(msg, FutureWarning)
# Lachnospiraceae_NK4A136_group
# /Users/CMonzo/software/miniconda/lib/python3.9/site-packages/seaborn/categorical.py:166: FutureWarning: Setting a gradient palette using color= is deprecated and will be removed in version 0.13. Set `palette='dark:.25'` for same effect.
#   warnings.warn(msg, FutureWarning)
# Staphylococcus
# /Users/CMonzo/software/miniconda/lib/python3.9/site-packages/seaborn/categorical.py:166: FutureWarning: Setting a gradient palette using color= is deprecated and will be removed in version 0.13. Set `palette='dark:.25'` for same effect.
#   warnings.warn(msg, FutureWarning)
# Muribaculaceae
# /Users/CMonzo/software/miniconda/lib/python3.9/site-packages/seaborn/categorical.py:166: FutureWarning: Setting a gradient palette using color= is deprecated and will be removed in version 0.13. Set `palette='dark:.25'` for same effect.
#   warnings.warn(msg, FutureWarning)
